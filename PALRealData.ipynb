# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from transformers import DistilBertTokenizer, DistilBertModel
import pandas as pd

# Load data
splits = {
    'train': 'data/train-00000-of-00001.parquet', 
    'validation': 'data/validation-00000-of-00001.parquet', 
    'test': 'data/test-00000-of-00001.parquet'
}
df = pd.read_parquet("hf://datasets/MichaelR207/prism_personalized_1023/" + splits["train"]).sample(3000)


# Model for shared mapping function f
class SharedMapping(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(SharedMapping, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim, output_dim),
            nn.ReLU(),
            nn.Linear(output_dim, output_dim)
        )

    def forward(self, x):
        return self.fc(x)
    

# Transformer-based embedding
class TextEmbedder:
    def __init__(self, model_name="distilbert-base-uncased"):
        self.tokenizer = DistilBertTokenizer.from_pretrained(model_name)
        self.model = DistilBertModel.from_pretrained(model_name)

    def encode(self, texts):
        tokens = self.tokenizer(texts, return_tensors='pt', padding=True, truncation=True)
        with torch.no_grad():
            embeddings = self.model(**tokens).last_hidden_state.mean(dim=1)  # Mean pooling
        return embeddings

# Step 1: Create a mapping from user_id strings to unique integer indices
unique_user_ids = df['user_id'].unique()
user_id_mapping = {user_id: idx for idx, user_id in enumerate(unique_user_ids)}
num_users = len(unique_user_ids)  # Update number of users
print(user_id_mapping)

# Step 2: Update the PreferenceDataset to use the user_id mapping
class PreferenceDataset(Dataset):
    def __init__(self, dataframe, text_embedder, user_id_mapping):
        self.dataframe = dataframe
        self.text_embedder = text_embedder
        self.user_id_mapping = user_id_mapping

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        
        # Extract text content
        context_text = row['context'][0]['content']
        chosen_text = row['chosen']['content']
        rejected_text = row['rejected']['content']
        
        # Get embeddings for context, chosen, rejected
        context_embed = self.text_embedder.encode([context_text])
        chosen_embed = self.text_embedder.encode([chosen_text])
        rejected_embed = self.text_embedder.encode([rejected_text])
        
        # Map user_id to index
        user_id = self.user_id_mapping[row['user_id']]
        
        # Set preference label
        label = torch.tensor(1.0 if row['chosen_score'] > row['rejected_score'] else 0.0)
        
        return context_embed.squeeze(0), chosen_embed.squeeze(0), rejected_embed.squeeze(0), user_id, label



class PAL_A(nn.Module):
    def __init__(self, input_dim, output_dim, num_prototypes, num_users):
        super(PAL_A, self).__init__()
        self.shared_mapping = SharedMapping(input_dim, output_dim)
        self.prototypes = nn.Parameter(torch.randn(num_prototypes, output_dim))
        self.user_weights = nn.Parameter(torch.rand(num_users, num_prototypes))
        self.num_users = num_users

    def forward(self, context, choice_embed, user_id):
        f_context = self.shared_mapping(context)
        f_choice = self.shared_mapping(choice_embed)  # Differentiate chosen/rejected
        if user_id is None:
            a_i = torch.matmul(self.user_weights.mean(dim=0), self.prototypes)
        else:
            a_i = torch.matmul(self.user_weights[user_id], self.prototypes)
        #print(a_i.shape)
        #print(user_id)
        #a_i = torch.matmul(self.user_weights[user_id], self.prototypes)
        # Calculate similarity for choice and context separately
        reward = torch.sum(f_choice * a_i, dim=1)  # Dot product for similarity
        #print(reward.shape)
        return reward

"""Using Context"""

# class PAL_A(nn.Module):
#     def __init__(self, input_dim, output_dim, num_prototypes, num_users):
#         super(PAL_A, self).__init__()
#         self.shared_mapping = SharedMapping(input_dim, output_dim)
#         self.prototypes = nn.Parameter(torch.randn(num_prototypes, output_dim))
#         self.user_weights = nn.Parameter(torch.rand(num_users, num_prototypes))
#         self.num_users = num_users

#     def forward(self, context, choice_embed, user_id=None):
#         f_context = self.shared_mapping(context)
#         f_choice = self.shared_mapping(choice_embed)
        
#         combined = torch.cat((f_context, f_choice), dim=1)
#         context_aware_choice = nn.Linear(2 * f_choice.size(1), f_choice.size(1)).to(context.device)(combined)
        
#         if user_id is None:
#             a_i = self.prototypes.mean(dim=0)  # For unseen users
#         else:
#             a_i = torch.matmul(self.user_weights[user_id], self.prototypes)
        
#         # Calculate reward based on context-aware choice embedding
#         reward = torch.sum(context_aware_choice * a_i, dim=1)
#         return reward


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
text_embedder = TextEmbedder()
input_dim = 768  # For DistilBERT embedding dimensions
output_dim = 128
num_prototypes = 5
num_users = len(df['user_id'].unique())

model = PAL_A(input_dim=input_dim, output_dim=output_dim, num_prototypes=num_prototypes, num_users=num_users).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.0001)

def preference_loss(reward_chosen, reward_rejected, label):
    #print(reward_chosen)
    #print(reward_rejected)
    diff = reward_chosen - reward_rejected
    #print("Reward Difference:", diff) 
    return torch.nn.functional.binary_cross_entropy_with_logits(diff, label)

# Training Loop
def train_model(model, dataloader, optimizer, num_epochs=1):
    model.train()
    for epoch in range(num_epochs):
        total_loss = 0
        for context, chosen, rejected, user_id, label in dataloader:
            context, chosen, rejected, label = context.to(device), chosen.to(device), rejected.to(device), label.to(device)
            user_id = user_id.to(device)
            

            reward_chosen = model(context, chosen, user_id)
            reward_rejected = model(context, rejected, user_id)
            loss = preference_loss(reward_chosen, reward_rejected, label)
            optimizer.zero_grad()
            loss.backward()
            
            optimizer.step()
            total_loss += loss.item()
        
        print(f'Epoch {epoch+1}/{num_epochs}, Loss: {total_loss/len(dataloader)}')


train_dataset = PreferenceDataset(df[df['split'] == 'train'], text_embedder, user_id_mapping)
train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True)

train_model(model, train_dataloader, optimizer)
# Out:
# {'user859': 0, 'user710': 1, 'user549': 2, 'user727': 3, 'user844': 4, 'user702': 5, 'user931': 6, 'user939': 7, 'user778': 8, 'user571': 9, 'user509': 10, 'user771': 11, 'user95': 12, 'user992': 13, 'user510': 14, 'user976': 15, 'user546': 16, 'user648': 17, 'user811': 18, 'user622': 19, 'user898': 20, 'user764': 21, 'user674': 22, 'user981': 23, 'user812': 24, 'user66': 25, 'user925': 26, 'user576': 27, 'user742': 28, 'user889': 29, 'user826': 30, 'user679': 31, 'user886': 32, 'user748': 33, 'user92': 34, 'user699': 35, 'user682': 36, 'user517': 37, 'user802': 38, 'user822': 39, 'user84': 40, 'user5': 41, 'user776': 42, 'user749': 43, 'user750': 44, 'user921': 45, 'user542': 46, 'user961': 47, 'user754': 48, 'user665': 49, 'user600': 50, 'user539': 51, 'user598': 52, 'user880': 53, 'user860': 54, 'user486': 55, 'user706': 56, 'user566': 57, 'user738': 58, 'user728': 59, 'user794': 60, 'user777': 61, 'user878': 62, 'user77': 63, 'user955': 64, 'user715': 65, 'user739': 66, 'user480': 67, 'user914': 68, 'user930': 69, 'user772': 70, 'user497': 71, 'user636': 72, 'user520': 73, 'user816': 74, 'user60': 75, 'user53': 76, 'user489': 77, 'user851': 78, 'user963': 79, 'user524': 80, 'user612': 81, 'user593': 82, 'user639': 83, 'user807': 84, 'user589': 85, 'user58': 86, 'user478': 87, 'user500': 88, 'user936': 89, 'user579': 90, 'user592': 91, 'user609': 92, 'user803': 93, 'user610': 94, 'user829': 95, 'user854': 96, 'user692': 97, 'user581': 98, 'user616': 99, 'user943': 100, 'user975': 101, 'user784': 102, 'user855': 103, 'user49': 104, 'user507': 105, 'user790': 106, 'user557': 107, 'user711': 108, 'user757': 109, 'user74': 110, 'user823': 111, 'user75': 112, 'user673': 113, 'user877': 114, 'user551': 115, 'user640': 116, 'user621': 117, 'user917': 118, 'user928': 119, 'user964': 120, 'user972': 121, 'user895': 122, 'user482': 123, 'user536': 124, 'user730': 125, 'user582': 126, 'user666': 127, 'user602': 128, 'user719': 129, 'user977': 130, 'user858': 131, 'user820': 132, 'user908': 133, 'user729': 134, 'user76': 135, 'user68': 136, 'user473': 137, 'user570': 138, 'user773': 139, 'user703': 140, 'user652': 141, 'user606': 142, 'user558': 143, 'user883': 144, 'user846': 145, 'user924': 146, 'user519': 147, 'user817': 148, 'user881': 149, 'user987': 150, 'user96': 151, 'user687': 152, 'user678': 153, 'user798': 154, 'user599': 155, 'user782': 156, 'user760': 157, 'user944': 158, 'user966': 159, 'user580': 160, 'user538': 161, 'user950': 162, 'user63': 163, 'user635': 164, 'user607': 165, 'user628': 166, 'user789': 167, 'user801': 168, 'user916': 169, 'user50': 170, 'user882': 171, 'user488': 172, 'user533': 173, 'user490': 174, 'user893': 175, 'user959': 176, 'user604': 177, 'user997': 178, 'user59': 179, 'user799': 180, 'user824': 181, 'user800': 182, 'user780': 183, 'user871': 184, 'user554': 185, 'user874': 186, 'user887': 187, 'user506': 188, 'user787': 189, 'user470': 190, 'user714': 191, 'user947': 192, 'user698': 193, 'user94': 194, 'user677': 195, 'user838': 196, 'user508': 197, 'user935': 198, 'user586': 199, 'user942': 200, 'user563': 201, 'user670': 202, 'user594': 203, 'user870': 204, 'user770': 205, 'user758': 206, 'user795': 207, 'user65': 208, 'user613': 209, 'user695': 210, 'user617': 211, 'user769': 212, 'user982': 213, 'user646': 214, 'user835': 215, 'user69': 216, 'user718': 217, 'user862': 218, 'user892': 219, 'user615': 220, 'user847': 221, 'user842': 222, 'user655': 223, 'user971': 224, 'user521': 225, 'user603': 226, 'user649': 227, 'user856': 228, 'user618': 229, 'user722': 230, 'user596': 231, 'user631': 232, 'user683': 233, 'user765': 234, 'user541': 235, 'user707': 236, 'user595': 237, 'user940': 238, 'user657': 239, 'user920': 240, 'user47': 241, 'user57': 242, 'user985': 243, 'user911': 244, 'user79': 245, 'user958': 246, 'user919': 247, 'user766': 248, 'user690': 249, 'user578': 250, 'user747': 251, 'user700': 252, 'user792': 253, 'user97': 254, 'user833': 255, 'user995': 256, 'user938': 257, 'user55 ...
# Epoch 1/1, Loss: 0.6751552496818786

# %%
example_row = df.iloc[78]
context_text = example_row['context'][0]['content']  # Assuming context is a list of dicts with a 'content' key
chosen_text = example_row['chosen']['content']       # Assuming chosen and rejected are dicts with a 'content' key
rejected_text = example_row['rejected']['content']

print("\nExample Data Point:")
print("Context:", context_text)
print("Chosen:", chosen_text)
print("Rejected:", rejected_text)


def make_prediction(model, context_text, chosen_text, rejected_text):
    model.eval()  # Set model to evaluation mode
    
    # Convert text data to embeddings
    context_embed = text_embedder.encode(context_text).to(device)
    chosen_embed = text_embedder.encode(chosen_text).to(device)
    rejected_embed = text_embedder.encode(rejected_text).to(device)

    # Choose an example user_id (in practice, use the specific user_id mapping)
    user_id = torch.tensor([78], dtype=torch.long).to(device)  # Example user_id 0

    # Get rewards for chosen and rejected
    reward_chosen = model(context_embed, chosen_embed, user_id)
    reward_rejected = model(context_embed, rejected_embed, user_id)

    # Prediction based on reward values
    prediction = "chosen" if reward_chosen > reward_rejected else "rejected"
    print(f"\nPrediction: {prediction}")
    print(f"Reward for Chosen: {reward_chosen.item()}, Reward for Rejected: {reward_rejected.item()}")

# Test prediction with an example data point
make_prediction(model, context_text, chosen_text, rejected_text)
# Out:
# Example Data Point:
# Context: red or blue
# Chosen: Sure, I'd be happy to help! Would you like to know the difference between red and blue, or perhaps something else?
# Rejected: As Coral, an AI chatbot designed to assist humans in a conversational manner, I do not have personal preferences or opinions. I can, however, provide information or generate responses based on my training to help answer your queries to the best of my knowledge and abilities. If you have any specific questions or requests, feel free to ask me, and I'll do my best to assist you!
#
# Prediction: chosen
# Reward for Chosen: 1.3204188346862793, Reward for Rejected: 0.15617117285728455

# %%
# Step 1: Check for Consistent Mapping
unique_user_ids = df['user_id'].unique()
mapped_indices = set(user_id_mapping.values())

if len(user_id_mapping) != len(unique_user_ids):
    print("Error: Inconsistent mapping. The number of unique user_ids does not match the size of user_id_mapping.")
else:
    print("User ID mapping is consistent with the number of unique user IDs.")

# Step 2: Verify Mapping Coverage
missing_user_ids = [user_id for user_id in unique_user_ids if user_id not in user_id_mapping]
if missing_user_ids:
    print(f"Error: Missing user IDs in user_id_mapping: {missing_user_ids}")
else:
    print("All user IDs in the dataset are covered in user_id_mapping.")

# Step 3: Ensure No Out-of-Bounds Indices
if max(user_id_mapping.values()) >= num_users or min(user_id_mapping.values()) < 0:
    print("Error: Out-of-bounds indices in user_id_mapping.")
else:
    print("All mapped indices are within bounds.")

# Step 4: Spot-check Random Samples to Confirm Accuracy
import random
sample_user_ids = random.sample(list(unique_user_ids), min(5, len(unique_user_ids)))
print("Sample check of user_id_mapping:")
for user_id in sample_user_ids:
    print(f"User ID: {user_id} -> Mapped Index: {user_id_mapping[user_id]}")

# Additional Check: Ensure each user_id maps to a unique integer index
inverse_mapping = {v: k for k, v in user_id_mapping.items()}
if len(inverse_mapping) != len(user_id_mapping):
    print("Error: Duplicate indices in user_id_mapping.")
else:
    print("Each user ID maps to a unique index.")
# Out:
# User ID mapping is consistent with the number of unique user IDs.
# All user IDs in the dataset are covered in user_id_mapping.
# All mapped indices are within bounds.
# Sample check of user_id_mapping:
# User ID: user925 -> Mapped Index: 0
# User ID: user509 -> Mapped Index: 1
# User ID: user84 -> Mapped Index: 17
# User ID: user941 -> Mapped Index: 31
# User ID: user870 -> Mapped Index: 34
# Each user ID maps to a unique index.

# %%
import torch

df_test = pd.read_parquet("hf://datasets/MichaelR207/prism_personalized_1023/" + splits["test"]).sample(1000)
print(df_test.shape)

def make_prediction(model, context_text, chosen_text, rejected_text, user_id):
    model.eval()  

    context_embed = text_embedder.encode([context_text]).to(device)
    chosen_embed = text_embedder.encode([chosen_text]).to(device)
    print(chosen_embed.shape)
    rejected_embed = text_embedder.encode([rejected_text]).to(device)

    if user_id in user_id_mapping:
        user_index = user_id_mapping[user_id]
        user_index = torch.tensor([user_index], dtype=torch.long).to(device)
    else:
        # Use average user weights for unseen users, pass None to indicate unseen user for model forward
        user_index = None
    print(user_index)

    reward_chosen = model(context_embed, chosen_embed, user_index)
    print(reward_chosen.shape)
    reward_rejected = model(context_embed, rejected_embed, user_index)
    diff = reward_chosen - reward_rejected

    # Using diff mean for reward tensors.
    prediction = "chosen" if diff.mean() > 0 else "rejected"  
    return prediction == "chosen"  

# Calculate accuracy
correct_predictions = 0
for idx, row in df_test.iterrows():
    print(idx)
    context_text = row['context'][0]['content'] 
    chosen_text = row['chosen']['content']
    rejected_text = row['rejected']['content']
    user_id = row['user_id']
    
    is_correct = make_prediction(model, context_text, chosen_text, rejected_text, user_id)
    correct_predictions += int(is_correct)  

accuracy = correct_predictions / len(df_test)
print(f"\nAccuracy on first 100 test points: {accuracy * 100:.2f}%")
# Out:
# (1000, 12)
# 14881
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12596
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 26419
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25419
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5838
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8829
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 327
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17754
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11467
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1254
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14952
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21521
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15893
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25631
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24339
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13713
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11801
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2178
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2165
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22208
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16121
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13743
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14739
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7086
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16080
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4397
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3915
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3683
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16214
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5579
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4677
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5391
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21135
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22391
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13581
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16531
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14508
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17467
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16813
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14501
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3079
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14299
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22716
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10716
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 568
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9928
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15142
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12118
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11830
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9356
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10217
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12196
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10763
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18640
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4725
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13824
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22675
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9394
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9599
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22213
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19974
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4147
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17471
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14191
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19714
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3237
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18105
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12271
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1735
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11009
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13118
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21283
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23351
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5459
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21868
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2729
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22358
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18266
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13176
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25564
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6349
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6727
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19300
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22170
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21728
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1284
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20476
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 224
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7083
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12428
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14363
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22662
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12591
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20099
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 587
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18236
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16941
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16164
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11102
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16974
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13033
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8204
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20789
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24915
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15603
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5504
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18163
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 26254
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23406
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5955
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8260
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8106
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22527
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23562
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17887
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5973
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20874
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8579
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7808
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20733
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22538
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14505
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11253
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3459
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5990
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19092
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23910
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1890
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19817
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16964
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14116
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17152
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 26081
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21720
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21733
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21406
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6738
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7501
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22367
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10741
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17034
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7927
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13670
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22168
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3392
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18334
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 913
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16557
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19128
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6042
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20183
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20188
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18407
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6898
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1123
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16594
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16872
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1668
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23696
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15008
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18709
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10643
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18944
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21975
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7636
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3433
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9525
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25930
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11462
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24967
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13479
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4090
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19462
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15992
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 162
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15103
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6453
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18424
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3608
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17309
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 26427
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9147
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 158
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14812
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24491
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7338
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10161
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20225
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8509
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19950
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16743
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24364
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25758
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23218
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13470
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15454
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6646
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1394
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24683
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8531
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9186
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24619
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8852
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6537
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10631
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9227
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14019
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5700
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7020
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18260
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21839
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18687
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4350
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6479
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21970
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 923
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17559
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11999
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15504
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21007
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1643
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1324
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6636
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13239
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18992
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13686
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5908
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8209
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3317
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13946
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3060
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2167
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16702
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9919
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14222
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9698
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24390
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13874
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13914
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21968
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10930
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21212
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15087
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3368
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18725
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4485
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 847
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15723
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23652
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20732
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6604
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9412
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10071
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21923
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16362
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7445
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 892
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14932
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9398
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15086
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14478
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 26578
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11346
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2886
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14810
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12057
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11066
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7330
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5418
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8497
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9658
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11016
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20980
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11726
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5096
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20949
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17596
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5016
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 714
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9399
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14128
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21622
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21232
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17746
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3908
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22263
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13762
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6873
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24903
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11616
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6928
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18205
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12616
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11231
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11103
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22922
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25046
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23179
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12305
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 484
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9927
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21851
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22781
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11929
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 26406
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10170
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10564
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5707
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20028
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22883
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19556
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4960
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24762
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10970
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2440
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1142
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11437
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21687
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1192
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14352
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14132
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11938
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7477
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5714
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12418
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3050
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11086
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4041
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9035
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1538
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10526
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7276
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3085
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23829
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18471
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18326
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5215
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9724
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3961
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10304
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15648
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14992
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11126
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19527
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18089
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15425
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20987
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16700
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22282
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7878
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2426
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11090
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19768
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20200
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5891
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5627
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2593
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1108
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14689
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17878
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14078
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21415
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7034
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3599
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2173
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16337
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23231
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4647
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22092
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19007
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 62
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9106
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19511
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1103
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24469
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16937
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10622
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 26228
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10893
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5660
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9953
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21473
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14987
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16613
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16019
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23335
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3969
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14105
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7766
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14309
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14698
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21627
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6816
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2672
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9725
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19478
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13196
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14803
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14272
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 26645
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22031
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16741
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24534
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9289
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11000
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3931
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3776
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24963
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16736
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16096
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12845
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20493
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18499
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3363
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3867
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16970
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8791
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25727
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3022
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22610
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22829
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2724
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6132
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23929
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13962
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19840
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14690
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7466
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 26137
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16255
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4369
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23420
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25975
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7169
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20785
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12917
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17312
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21698
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5952
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2347
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19325
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22688
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1063
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 170
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13083
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15519
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4092
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10969
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5513
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25702
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14192
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21375
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6683
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15526
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4989
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9221
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15554
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25638
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7935
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7336
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 84
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22471
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9949
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12614
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5575
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17564
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15752
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20740
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15733
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6587
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13150
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24682
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7600
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25606
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6288
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1580
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16350
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5340
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25103
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20125
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 728
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7300
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6500
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4305
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13541
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17714
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4278
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15020
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15914
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15372
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24576
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13560
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10918
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4202
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9906
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17971
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11431
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10766
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1400
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24687
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23815
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18943
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20235
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2940
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17832
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3117
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22428
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17193
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4058
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 124
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16932
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1358
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23952
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2746
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14536
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25119
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18108
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13719
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23065
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 26139
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12125
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16673
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3591
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1904
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1069
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20381
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15839
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6806
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25747
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2211
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5986
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23937
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11566
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18228
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17194
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6096
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3717
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5245
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3165
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22504
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9694
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12367
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24575
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2287
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6249
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15751
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22128
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21410
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21897
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8520
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22877
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3847
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16815
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4073
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10666
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16776
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25954
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10691
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21870
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 26526
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 70
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19733
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24986
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10077
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8233
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25585
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20506
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1446
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14792
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9971
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16063
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17122
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22788
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16373
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10555
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25528
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2591
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21245
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24932
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1080
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24415
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18222
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22004
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3312
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 412
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20770
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11472
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11028
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14436
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4121
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4607
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16091
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13240
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18067
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13490
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25746
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12654
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5213
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21949
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25020
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20307
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3506
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10220
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18352
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6772
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5703
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14663
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4763
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25946
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1457
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15982
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23236
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 632
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9710
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4688
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11113
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7425
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14876
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3492
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8250
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16024
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19123
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25317
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6735
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4544
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11156
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13215
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18460
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2916
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17279
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 800
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21555
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17453
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15356
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9331
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1416
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16303
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7989
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20161
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22929
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4628
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4067
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17571
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9425
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19834
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14331
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9432
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24059
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24410
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16708
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23507
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13151
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21273
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11101
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12287
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22392
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23427
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14190
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19932
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8721
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2550
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12460
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 57
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17934
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4108
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24923
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7796
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10190
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5381
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19183
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3367
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8007
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12102
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23889
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23763
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9995
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2514
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19100
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13813
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6303
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7301
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15656
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7637
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 26529
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13772
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2960
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22196
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19463
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25324
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1515
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25205
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21249
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11366
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21924
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3207
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5224
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1504
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17359
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9954
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9680
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5827
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19696
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19472
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19504
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3812
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16651
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 721
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24004
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12962
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16600
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12593
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20468
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14824
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12110
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21371
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11975
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8536
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3028
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10437
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14089
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2077
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6207
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21439
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11355
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21788
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15046
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17780
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15216
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21630
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3478
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11629
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 26067
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17134
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19935
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8585
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11004
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6974
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25478
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10317
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1176
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16775
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10674
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15730
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21811
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10272
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24472
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6513
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5425
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18279
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12896
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10225
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19659
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15597
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21983
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8732
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13229
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3693
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22087
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8313
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9111
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 130
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17588
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3095
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6087
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25743
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22459
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5510
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6061
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9875
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5874
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11937
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25102
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15564
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18833
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5845
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17634
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18895
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19449
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15246
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3788
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24764
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20756
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25814
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23557
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10369
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 957
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12311
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17015
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8713
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 26249
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12737
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13389
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 876
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4853
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12254
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19925
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25579
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11962
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15429
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9545
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15809
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16857
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20638
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4914
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25026
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16979
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25896
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13224
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13057
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24912
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24758
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17078
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14404
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6121
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23561
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23480
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4343
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15970
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24552
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24276
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9790
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9867
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2105
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5212
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12718
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3295
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22347
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23543
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14135
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13433
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17806
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9371
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11143
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 26584
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16780
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4386
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25810
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5380
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23456
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22310
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15646
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4819
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23319
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7509
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23282
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 26346
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8079
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5642
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14927
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22387
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6632
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 114
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16824
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16059
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14912
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8203
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13148
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11458
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25958
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10162
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4046
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5247
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19436
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3489
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23010
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19099
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13695
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9146
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4259
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8555
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1575
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5385
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6774
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6405
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16039
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 989
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1674
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15239
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25032
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2282
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23305
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5957
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8505
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7274
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22980
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12074
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1834
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19479
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22748
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2976
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16819
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23310
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8606
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 867
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3526
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8057
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15130
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25310
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9809
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24898
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10058
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3127
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18444
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17942
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 26364
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20667
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2084
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9487
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 21885
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17170
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3853
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1900
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19697
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12090
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13782
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3481
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23649
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11170
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24258
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24879
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22821
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22272
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15124
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17897
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16583
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18955
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1664
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23235
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18478
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24132
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14448
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5233
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14177
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11241
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7727
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24161
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20802
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 182
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20749
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16240
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18697
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5820
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9486
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12529
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9488
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13646
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4963
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1410
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12670
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7971
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3576
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6040
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 19355
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24093
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3472
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15423
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1709
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 8936
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 17787
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2279
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 24341
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20858
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16310
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6628
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 16863
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15569
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 14979
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 233
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4461
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20845
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 18851
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 15347
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3476
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 10413
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 22382
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 7763
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 13035
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 20361
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25622
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3457
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 3313
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6236
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 11810
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 153
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4865
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 433
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 25296
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 5840
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 6895
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4355
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 23176
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9233
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 4833
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12554
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 12242
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 1298
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 9560
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
# 2303
# torch.Size([1, 768])
# None
# torch.Size([1, 128])
#
# Accuracy on first 100 test points: 60.50%
